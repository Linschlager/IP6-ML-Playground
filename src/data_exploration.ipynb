# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../data.csv", delimiter=";")

# %%
df.head()
# Out:
#    CuAge  CuMale  CuFemale  CuEducation  Relationship  RelationshipAge  PaAge  \
# 0     30       1         0            5           1.0              6.0   29.0
# 1     48       0         1            0           NaN              NaN    NaN
# 2     25       0         1            2           2.0              2.0   59.0
# 3     41       1         0            2           1.0              1.0   20.0
# 4     44       0         1            2           2.0              3.0   47.0
#
#    PaMale  PaFemale  PaEducation  NumKids  KidsMinAge  KidsMaxAge  KidsAvgAge  \
# 0     0.0       1.0          3.0        2        10.0        10.0   10.000000
# 1     NaN       NaN          NaN        2        16.0        25.0   20.500000
# 2     1.0       0.0          2.0        3         1.0         4.0    2.333333
# 3     0.0       1.0          1.0        0         NaN         NaN         NaN
# 4     1.0       0.0          3.0        0         NaN         NaN         NaN
#
# ...

# %%
df.describe()
# Out:
#                CuAge         CuMale       CuFemale   CuEducation  \
# count  100000.000000  100000.000000  100000.000000  100000.00000
# mean       42.166830       0.501020       0.498980       2.49809
# std        12.576876       0.500001       0.500001       1.70841
# min        19.000000       0.000000       0.000000       0.00000
# 25%        31.000000       0.000000       0.000000       1.00000
# 50%        42.000000       1.000000       0.000000       3.00000
# 75%        53.000000       1.000000       1.000000       4.00000
# max        64.000000       1.000000       1.000000       5.00000
#
#        Relationship  RelationshipAge         PaAge        PaMale  \
# count  50146.000000     37596.000000  50146.000000  50146.000000
# mean       1.297970         8.958905     42.081183      0.498185
# std        0.898828         7.681095     12.567651      0.500002
# min        0.000000         1.000000     19.000000      0.000000
# ...

# %%
sns.pairplot(df, corner=True)

# %%
sns.countplot(x="NumKids", hue="KidsMedAge", data=df)
plt.legend([],[], frameon=False)
